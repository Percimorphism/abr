# %%
import pgeocode
import pandas as pd
pd.set_option("display.max_rows", None)

# %%
dc = pd.read_excel("dcbr-zip-codes.xlsx", sheet_name='count')
#display(dc)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
dc.columns = ['zip', 'count']
display(dc)
# Out:
#              zip  count
# 0          20002    678
# 1          20003    589
# 2          20009    471
# 3          22201    446
# 4          22201    446
# 5          20001    417
# 6          20011    389
# 7          22314    371
# 8          22314    371
# 9          20008    302
# 10         22207    293
# 11         22207    293
# 12         20007    289
# 13         22202    263
# 14         22202    263
# 15         22204    259
# 16         22204    259
# 17         20854    250
# 18         20016    247
# 19         20010    237
# 20         20814    236
# 21         22205    234
# 22         22205    234
# 23         20910    231
# 24         20817    228
# 25         22203    209
# 26         22203    209
# 27         20024    209
# 28         22003    165
# 29         22003    165
# 30         20850    165
# 31         20850    165
# 32         20774    160
# 33         20017    158
# 34         22304    151
# 35         22304    151
# 36         20020    151
# ...

# %%
nomi = pgeocode.Nominatim('US')
loc = nomi.query_postal_code(dc['zip'].to_list())
